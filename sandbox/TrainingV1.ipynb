# %% [markdown]
# ## Training Bayesian Network

# %% [markdown]
# ### Get updated precision matrix from data

# %%
# Import libraries 
import pandas as pd 
import numpy as np

# %%
# Load CO2 and Ethylene gas mixture file
header_names = ["Time", "CO2", "Ethylene", "Sensor1", "Sensor2", "Sensor3", "Sensor4", "Sensor5", "Sensor6", "Sensor7", "Sensor8", "Sensor9", "Sensor10", "Sensor11", "Sensor12", "Sensor13", "Sensor14", "Sensor15", "Sensor16"]
df = pd.read_csv("data/gas-mixture/ethylene_CO.txt", delim_whitespace=True, skiprows=[0], header=None, names=header_names)

# Set time column as index
df = df.set_index("Time")

# %%
# Check data frame
df.head()
# Out:
#       CO2  Ethylene  Sensor1  Sensor2  Sensor3  Sensor4  Sensor5  Sensor6  \
# Time
# 0.00  0.0       0.0   -50.85    -1.95   -41.82     1.30    -4.07   -28.73
# 0.01  0.0       0.0   -49.40    -5.53   -42.78     0.49     3.58   -34.55
# 0.01  0.0       0.0   -40.04   -16.09   -27.59     0.00    -7.16   -42.14
# 0.03  0.0       0.0   -47.14   -10.57   -32.28     4.40   -11.22   -37.94
# 0.04  0.0       0.0   -33.58   -20.79   -33.25     6.03     3.42   -34.22
#
#       Sensor7  Sensor8   Sensor9  Sensor10  Sensor11  Sensor12  Sensor13  \
# Time
# 0.00   -13.49    -3.25  55139.95  50669.50   9626.26   9762.62  24544.02
# 0.01    -9.59     5.37  54395.77  50046.91   9433.20   9591.21  24137.13
# 0.01   -12.52    -5.86  53960.02  49299.30   9324.40   9449.81  23628.90
# 0.03    -7.16    -1.14  53047.71  48907.00   9170.64   9305.58  23101.66
# 0.04   -14.46     8.31  52700.28  48330.96   9073.64   9163.47  22689.54
#
#       Sensor14  Sensor15  Sensor16
# Time
# 0.00  21420.68   7650.61   6928.42
# 0.01  20930.33   7498.79   6800.66
# 0.01  20504.94   7369.67   6697.47
# 0.03  20101.42   7285.13   6578.52
# 0.04  19694.07   7156.74   6468.32

# %%
# Transform data frame in numpy matrix
# data = (df.head(1000)).values
data = df.values

# %%
# Calculate mean of each column
x_mean = data.mean(0)

# %%
# Calculate s
s = data-x_mean
s = (s.T).dot(s)

# %%
# Calculate M
M = data.size

# %%
# Assuming prior ignorance. v = 0 and beta = 0
beta_update = s
mi_update = x_mean
v_update = M
alpha_update = M-1

# %%
# number of random variables
n = 18 

# Calculate Phi_Update
phi_update = (v_update+1)/(v_update*(alpha_update-n+1))
phi_update *= beta_update

# %%
# Calculate Precision Update
precision_update = np.linalg.inv(phi_update)

# %% [markdown]
# ### Calculate Symbolic Precision Matrix

# %%
import sympy as sp

# %%
# Startup and configuration
n = 18         # 18 random variables
b = [None]*n   # list to initialize bij symbols
v = [None]*n   # list to initialize vi  symbols (variance)

# %%
# Create all bij symbols (from b11 to b1818)
for i in range(n):
    symbol_string = ''
    for j in range(i+1):
        symbol_string += 'b' + str(i+1) + '_' + str(j+1) + ' '
    b[i] = sp.symbols(symbol_string)

# %%
# Start B matrix using bij symbols
B = sp.zeros(n,n)
B[0, 0] = b[0]       # first symbols is exception not being a list of list
for i in range(1,n):
    for j in range(i+1):
        B[i,j] = b[i][j]

# %%
# Create all v, variance symbols (from v1 to v18)
for i in range(n):
    v[i] = sp.symbols(r'\sigma' + str(i+1))

# %%
T = sp.zeros(1,1)
T[0,0] = (1/v[0])
for i in range (1, 18):
    # Initialize ti
#    t = (1/v[i])**2
    t = (1/v[i]) # For simplicity variance will be represented without the square
    tt = sp.zeros(1,1)
    tt[0,0] = t
    
    # Initialize  
    TMP = sp.zeros(i+1,i+1)
    
    ## Populate                                                ## row, col
    TMP[0:i,   0:i]   = T + t*sp.Transpose(B[i,0:i])*B[i,0:i]  ## [0 , 0]
    TMP[0:i,   i:i+1] = -sp.Transpose(t*B[i,0:i])              ## [0 , 1]
    TMP[i:i+1, 0:i]   = -t*B[i,0:i]                            ## [1 , 0]
    TMP[i:i+1, i:i+1] = tt                                     ## [1 , 1]
    
    
    T = TMP
# T

# %% [markdown]
# ### Solve Precision Matrix (get parameters $\sigma_{ij}^*$ and $b_{ij}$)

# %%
# Start Equation list
counter = 0
EQ = sp.zeros(171, 1)
for j in reversed(range(0,n)):
    for i in reversed(range(0,j+1)):
        # EQ[(i-1)*n + j] = T[i][j]-precision_update[i][j]        
        EQ[counter] = T[i, j]-precision_update[i, j]
        counter += 1

# %%
solution = sp.solve(EQ[0:140], dict=True, manual=True)

# %%
solution
# Out:
# [{\sigma10: 86.6964814010731,
#   \sigma11: 2229.10172798706,
#   \sigma12: 117.981287969481,
#   \sigma13: 482.325259658590,
#   \sigma14: 53.6899146023380,
#   \sigma15: 177.366475648499,
#   \sigma16: 9.89085183517062,
#   \sigma17: 187.401313076867,
#   \sigma18: 146.501421080263,
#   \sigma8: 50.1298092341350,
#   \sigma9: 1135.68465692175,
#   b10_1: 0.0790667559037269,
#   b10_2: 0.801785334838480,
#   b10_3: 0.00495353996920800,
#   b10_4: 0.00246893168261756,
#   b10_5: -0.355116621020493,
#   b10_6: 0.300302834268022,
#   b10_7: 0.127659940382195,
#   b10_8: -0.303885774340900,
#   b10_9: 1.10257815525530,
#   b11_1: 0.555799009653353,
#   b11_10: 0.371837084530704,
#   b11_2: -2.30762820647062,
#   b11_3: 0.636959350421081,
#   b11_4: -0.0290435686630750,
#   b11_5: -1.69375661270104,
#   b11_6: 1.43792049618018,
#   b11_7: -3.63749178975224,
#   b11_8: 1.10547597951064,
#   b11_9: 0.221257415224033,
#   b12_1: -0.00925344661016664,
#   b12_10: -0.109556891310356,
#   b12_11: 0.892668832487929,
#   b12_2: -0.0271496313440142,
#   b12_3: 0.0580107533445714,
#   b12_4: -0.00328110637279503,
#   b12_5: 0.173682004769155,
#   b12_6: -0.169272388870834,
#   b12_7: 0.760144379227476,
#   b12_8: -0.536491051734116,
#   b12_9: 0.0675871568611510,
#   b13_1: -0.00135713477093439,
#   b13_10: 0.893900959691846,
#   b13_11: -0.227503336550689,
#   b13_12: 0.435635579592699,
#   b13_2: -1.79036827040356,
#   b13_3: -0.0600382142482089,
#   b13_4: 0.0114214557567190,
#   b13_5: -0.561835105383965,
#   b13_6: 1.78892178107891,
#   b13_7: -4.02955139284940,
#   b13_8: 2.40222037357913,
#   b13_9: -0.837346749676299,
#   b14_1: -0.00891460033486964,
#   b14_10: -0.00446907114991209,
#   b14_11: 0.0602094773485992,
#   b14_12: 0.00676476572229098,
#   b14_13: 0.744837899979669,
#   b14_2: -0.736502111496009,
#   b14_3: 0.0242432039009219,
#   b14_4: 0.00408304226177541,
#   b14_5: 0.284154669942114,
#   b14_6: -0.427071385070081,
#   b14_7: -0.335771293483985,
#   b14_8: 0.689725521197949,
#   b14_9: 0.138544579004205,
#   b15_1: -0.154208080050785,
#   b15_10: -0.339726775979329,
#   b15_11: -0.124243729003337,
#   b15_12: 0.384818846572023,
#   b15_13: -0.204140289600385,
#   b15_14: 0.322154460946278,
#   b15_2: 1.60578863590427,
#   b15_3: -0.183647958382090,
#   b15_4: 0.0101319801255254,
#   b15_5: 0.627745248074320,
#   b15_6: -0.554049455236761,
#   b15_7: 1.90191751339318,
#   b15_8: -0.752933561948557,
#   b15_9: 0.100385900761581,
#   b16_1: 0.0134872273675574,
#   b16_10: 0.0178012811013940,
#   b16_11: -0.0273582306892942,
#   b16_12: 0.0749283893956492,
#   b16_13: 0.0103275651599949,
#   b16_14: -0.0191862828550084,
#   b16_15: 0.790837534752978,
#   b16_2: -0.498120799464034,
#   b16_3: -0.00893728849298911,
#   b16_4: -0.00104735209441394,
#   b16_5: 0.0494004677047046,
#   b16_6: -0.0449622888877615,
#   b16_7: 0.142199117776172,
#   b16_8: -0.0576935556209993,
#   b16_9: -0.00968083818838875,
#   b17_1: 0.00257419120537931,
#   b17_10: 0.987646849770496,
#   b17_11: 0.0432654015364539,
#   b17_12: -0.336956750714591,
#   b17_13: 1.03550529289213,
#   b17_14: 0.284149022076008,
#   b17_15: 0.640518793524666,
#   b17_16: -0.452941168765195,
#   b17_2: 3.12449030342068,
#   b17_3: -0.00224322718184565,
#   b17_4: 0.00718255214230583,
#   b17_5: 0.161861830616818,
#   b17_6: -1.16149956288796,
#   b17_7: 0.793850370356913,
#   b17_8: -1.00745522898367,
#   b17_9: -0.201781369071333,
#   b18_1: 0.130601246873298,
#   b18_10: 0.533794312953015,
#   b18_11: 0.278745092914660,
#   b18_12: -0.148158993479284,
#   b18_13: 0.0923316691205710,
#   b18_14: 0.834104036490002,
#   b18_15: -1.47878731701383,
#   b18_16: 1.15169058706346,
#   b18_17: 0.00724779643076236,
#   b18_2: -1.51787496600518,
#   b18_3: -0.0466940867395865,
#   b18_4: 0.00154198693365485,
#   b18_5: -0.966071984823535,
#   b18_6: 0.311177481669583,
#   b18_7: -0.740528024864703,
#   b18_8: 1.00100740683130,
#   b18_9: 0.0555018630783249,
#   b8_4: 0.00166184458052151,
#   b8_5: 0.231263402165293,
#   b8_6: -0.289834668801461,
#   b8_7: 1.20341388195754,
#   b9_1: 0.233603433730239,
#   b9_2: 20.9858234114386,
#   b9_3: -0.0910830756983212,
#   b9_4: -0.0249416698831329,
#   b9_5: 2.06439718585961,
#   b9_6: -1.05941412805652,
#   b9_7: 1.72373975533362,
#   b9_8: -0.695736103289335}]

# %%
for i in range(len(EQ)):
    EQ[i] = EQ[i].subs(solution[0])

# %%
solution1 = sp.solve(EQ[140:171], dict=True, manual=True)

# %%
solution1
# Out:
# [{\sigma1: 1436.07355800653,
#   \sigma2: 1.75327557172758,
#   \sigma3: 19917.2091540482,
#   \sigma4: 127660.493593088,
#   \sigma5: 68531.9615300373,
#   \sigma6: 88.3523544898902,
#   \sigma7: 785.983180857272,
#   b2_1: -0.00166720447940115,
#   b3_1: 3.17862904421874,
#   b3_2: 17.4238281746323,
#   b4_1: -0.426989760115247,
#   b4_2: -30.0205034012173,
#   b4_3: 0.229805142897308,
#   b5_1: 0.167650573625252,
#   b5_2: 166.734351835911,
#   b5_3: 0.745561104410979,
#   b5_4: -0.0219222611748517,
#   b6_1: 0.0926464739279943,
#   b6_2: -0.580883989765739,
#   b6_3: 0.0820536664203228,
#   b6_4: 0.00598026586840613,
#   b6_5: 1.05867991271627,
#   b7_1: 0.413052966895524,
#   b7_2: 5.27769628413856,
#   b7_3: 0.170972544776660,
#   b7_4: 0.0401333008620466,
#   b7_5: -0.119365805723064,
#   b7_6: 0.275172514036572,
#   b8_1: 0.0902531962021726,
#   b8_2: -1.48927890971384,
#   b8_3: 0.0248569757798889}]

# %%
final_sol = solution[0]

# %%
final_sol.update(solution1[0])

# %%
final_sol
# Out:
# {\sigma1: 1436.07355800653,
#  \sigma10: 86.6964814010731,
#  \sigma11: 2229.10172798706,
#  \sigma12: 117.981287969481,
#  \sigma13: 482.325259658590,
#  \sigma14: 53.6899146023380,
#  \sigma15: 177.366475648499,
#  \sigma16: 9.89085183517062,
#  \sigma17: 187.401313076867,
#  \sigma18: 146.501421080263,
#  \sigma2: 1.75327557172758,
#  \sigma3: 19917.2091540482,
#  \sigma4: 127660.493593088,
#  \sigma5: 68531.9615300373,
#  \sigma6: 88.3523544898902,
#  \sigma7: 785.983180857272,
#  \sigma8: 50.1298092341350,
#  \sigma9: 1135.68465692175,
#  b10_1: 0.0790667559037269,
#  b10_2: 0.801785334838480,
#  b10_3: 0.00495353996920800,
#  b10_4: 0.00246893168261756,
#  b10_5: -0.355116621020493,
#  b10_6: 0.300302834268022,
#  b10_7: 0.127659940382195,
#  b10_8: -0.303885774340900,
#  b10_9: 1.10257815525530,
#  b11_1: 0.555799009653353,
#  b11_10: 0.371837084530704,
#  b11_2: -2.30762820647062,
#  b11_3: 0.636959350421081,
#  b11_4: -0.0290435686630750,
#  b11_5: -1.69375661270104,
#  b11_6: 1.43792049618018,
#  b11_7: -3.63749178975224,
#  b11_8: 1.10547597951064,
#  b11_9: 0.221257415224033,
#  b12_1: -0.00925344661016664,
#  b12_10: -0.109556891310356,
#  b12_11: 0.892668832487929,
#  b12_2: -0.0271496313440142,
#  b12_3: 0.0580107533445714,
#  b12_4: -0.00328110637279503,
#  b12_5: 0.173682004769155,
#  b12_6: -0.169272388870834,
#  b12_7: 0.760144379227476,
#  b12_8: -0.536491051734116,
#  b12_9: 0.0675871568611510,
#  b13_1: -0.00135713477093439,
#  b13_10: 0.893900959691846,
#  b13_11: -0.227503336550689,
#  b13_12: 0.435635579592699,
#  b13_2: -1.79036827040356,
#  b13_3: -0.0600382142482089,
#  b13_4: 0.0114214557567190,
#  b13_5: -0.561835105383965,
#  b13_6: 1.78892178107891,
#  b13_7: -4.02955139284940,
#  b13_8: 2.40222037357913,
#  b13_9: -0.837346749676299,
#  b14_1: -0.00891460033486964,
#  b14_10: -0.00446907114991209,
#  b14_11: 0.0602094773485992,
#  b14_12: 0.00676476572229098,
#  b14_13: 0.744837899979669,
#  b14_2: -0.736502111496009,
#  b14_3: 0.0242432039009219,
#  b14_4: 0.00408304226177541,
#  b14_5: 0.284154669942114,
#  b14_6: -0.427071385070081,
#  b14_7: -0.335771293483985,
#  b14_8: 0.689725521197949,
#  b14_9: 0.138544579004205,
#  b15_1: -0.154208080050785,
#  b15_10: -0.339726775979329,
#  b15_11: -0.124243729003337,
#  b15_12: 0.384818846572023,
#  b15_13: -0.204140289600385,
#  b15_14: 0.322154460946278,
#  b15_2: 1.60578863590427,
#  b15_3: -0.183647958382090,
#  b15_4: 0.0101319801255254,
#  b15_5: 0.627745248074320,
#  b15_6: -0.554049455236761,
#  b15_7: 1.90191751339318,
#  b15_8: -0.752933561948557,
#  b15_9: 0.100385900761581,
#  b16_1: 0.0134872273675574,
#  b16_10: 0.0178012811013940,
#  b16_11: -0.0273582306892942,
#  b16_12: 0.0749283893956492,
#  b16_13: 0.0103275651599949,
#  b16_14: -0.0191862828550084,
#  b16_15: 0.790837534752978,
#  b16_2: -0.498120799464034,
#  b16_3: -0.00893728849298911,
#  b16_4: -0.00104735209441394,
#  b16_5: 0.0494004677047046,
#  b16_6: -0.0449622888877615,
#  b16_7: 0.142199117776172,
#  b16_8: -0.0576935556209993,
#  b16_9: -0.00968083818838875,
#  b17_1: 0.00257419120537931,
#  b17_10: 0.987646849770496,
#  b17_11: 0.0432654015364539,
#  b17_12: -0.336956750714591,
#  b17_13: 1.03550529289213,
#  b17_14: 0.284149022076008,
#  b17_15: 0.640518793524666,
#  b17_16: -0.452941168765195,
#  b17_2: 3.12449030342068,
#  b17_3: -0.00224322718184565,
#  b17_4: 0.00718255214230583,
#  b17_5: 0.161861830616818,
#  b17_6: -1.16149956288796,
#  b17_7: 0.793850370356913,
#  b17_8: -1.00745522898367,
#  b17_9: -0.201781369071333,
#  b18_1: 0.130601246873298,
#  b18_10: 0.533794312953015,
#  b18_11: 0.278745092914660,
#  b18_12: -0.148158993479284,
#  b18_13: 0.0923316691205710,
#  b18_14: 0.834104036490002,
#  b18_15: -1.47878731701383,
#  b18_16: 1.15169058706346,
#  b18_17: 0.00724779643076236,
#  b18_2: -1.51787496600518,
#  b18_3: -0.0466940867395865,
#  b18_4: 0.00154198693365485,
#  b18_5: -0.966071984823535,
#  b18_6: 0.311177481669583,
#  b18_7: -0.740528024864703,
#  b18_8: 1.00100740683130,
#  b18_9: 0.0555018630783249,
#  b2_1: -0.00166720447940115,
#  b3_1: 3.17862904421874,
#  b3_2: 17.4238281746323,
#  b4_1: -0.426989760115247,
#  b4_2: -30.0205034012173,
#  b4_3: 0.229805142897308,
#  b5_1: 0.167650573625252,
#  b5_2: 166.734351835911,
#  b5_3: 0.745561104410979,
#  b5_4: -0.0219222611748517,
#  b6_1: 0.0926464739279943,
#  b6_2: -0.580883989765739,
#  b6_3: 0.0820536664203228,
#  b6_4: 0.00598026586840613,
#  b6_5: 1.05867991271627,
#  b7_1: 0.413052966895524,
#  b7_2: 5.27769628413856,
#  b7_3: 0.170972544776660,
#  b7_4: 0.0401333008620466,
#  b7_5: -0.119365805723064,
#  b7_6: 0.275172514036572,
#  b8_1: 0.0902531962021726,
#  b8_2: -1.48927890971384,
#  b8_3: 0.0248569757798889,
#  b8_4: 0.00166184458052151,
#  b8_5: 0.231263402165293,
#  b8_6: -0.289834668801461,
#  b8_7: 1.20341388195754,
#  b9_1: 0.233603433730239,
#  b9_2: 20.9858234114386,
#  b9_3: -0.0910830756983212,
#  b9_4: -0.0249416698831329,
#  b9_5: 2.06439718585961,
#  b9_6: -1.05941412805652,
#  b9_7: 1.72373975533362,
#  b9_8: -0.695736103289335}

# %%
import csv

w = csv.writer(open("output.csv", "w"))
for key, val in final_sol.items():
    w.writerow([str(key), val])

# %%
type(final_sol)
# Out:
# dict

# %%
x_mean
# Out:
# array([1.27620212e+02, 5.32043647e+00, 2.06561664e+03, 5.06218365e+02,
#        4.37253865e+03, 4.79924961e+03, 1.89495717e+03, 2.21469248e+03,
#        5.08663948e+03, 5.38542821e+03, 1.18624146e+03, 1.21925228e+03,
#        4.87107894e+03, 3.92624998e+03, 9.28187700e+02, 1.03577199e+03,
#        5.28932324e+03, 4.30968520e+03])
